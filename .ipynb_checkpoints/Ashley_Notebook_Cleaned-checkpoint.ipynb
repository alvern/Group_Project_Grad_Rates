# %%
# Add in Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Graduation Data

# %%
# Read in Graduation File from Excel
grad_file = "Resources/Copy of 2018 Graduation Indicators-1.xlsx"
grad_df = pd.read_excel(grad_file, sheet_name='School')

new_head = grad_df.iloc[3] 
grad_df2 = grad_df[4:] 
grad_df2.columns = new_head
grad_df2.head()
# Out:
# 3 \nData\nYear \nDistrict\nNumber \nDistrict\nType  \
# 4        17-18               0001               01
# 5        17-18               0001               01
# 6        17-18               0001               01
# 7        17-18               0001               01
# 8        17-18               0001               01
#
# 3               \nDistrict\nName \nSchool\nNumber           \nSchool\nName  \
# 4  Aitkin Public School District              001  Aitkin Secondary School
# 5  Aitkin Public School District              001  Aitkin Secondary School
# 6  Aitkin Public School District              001  Aitkin Secondary School
# 7  Aitkin Public School District              001  Aitkin Secondary School
# 8  Aitkin Public School District              001  Aitkin Secondary School
#
# 3 \nDemographic\nCategory \nDemographic\nDescription \nEnding\nStatus  \
# 4                       A               All Students         Graduate
# ...

# %%
list(grad_df2)
# Out:
# ['\nData\nYear',
#  '\nDistrict\nNumber',
#  '\nDistrict\nType',
#  '\nDistrict\nName',
#  '\nSchool\nNumber',
#  '\nSchool\nName',
#  '\nDemographic\nCategory',
#  '\nDemographic\nDescription',
#  '\nEnding\nStatus',
#  '\nFour \nYear Count',
#  '\nFour \nYear Total',
#  '\nFour \nYear Percent',
#  '\nFive \nYear Count',
#  '\nFive \nYear Total',
#  '\nFive \nYear Percent',
#  '\nSix \nYear Count',
#  '\nSix \nYear Total',
#  '\nSix \nYear Percent',
#  '\nSeven \nYear Count',
#  '\nSeven \nYear Total',
#  '\nSeven \nYear Percent',
#  '\nSchool \nClassification',
#  'School\nCounty\nNumber',
#  'School\nCounty\nName']

# %%
#Rename Columns
grad_df2.rename(columns = {'\nDistrict\nNumber':'District Number',
                           '\nDistrict\nType':'District Type',
                           '\nSchool\nNumber': 'School Number', 
                           '\nSchool\nName': 'School Name',
                           '\nDemographic\nDescription': 'Demographic Description',
                           '\nEnding\nStatus': 'Ending Status',
                           '\nFour \nYear Percent': 'Four Year Percent',
                           '\nFour \nYear Total': 'Four Year Total'}, inplace = True) 
grad_df2['School Name'] = grad_df2['School Name'].str.upper()

# %%
#Create ORGID for all schools
grad_df2["ORGID"] = grad_df2["District Type"].map(str) + grad_df2["District Number"].map(str) + grad_df2["School Number"] + "000"
grad_df2.head()
# Out:
# 3 \nData\nYear District Number District Type               \nDistrict\nName  \
# 4        17-18            0001            01  Aitkin Public School District
# 5        17-18            0001            01  Aitkin Public School District
# 6        17-18            0001            01  Aitkin Public School District
# 7        17-18            0001            01  Aitkin Public School District
# 8        17-18            0001            01  Aitkin Public School District
#
# 3 School Number              School Name \nDemographic\nCategory  \
# 4           001  AITKIN SECONDARY SCHOOL                       A
# 5           001  AITKIN SECONDARY SCHOOL                       A
# 6           001  AITKIN SECONDARY SCHOOL                       A
# 7           001  AITKIN SECONDARY SCHOOL                       A
# 8           001  AITKIN SECONDARY SCHOOL                       G
#
# 3 Demographic Description Ending Status \nFour \nYear Count      ...       \
# ...

# %%
# Drop unnecdessary columns
new_grad_df2 = grad_df2[['ORGID', 
                         'School Name', 
                         'Demographic Description',
                         'Ending Status', 
                         'Four Year Percent',
                         'Four Year Total']]
new_grad_df2.head()
# Out:
# 3         ORGID              School Name Demographic Description  \
# 4  010001001000  AITKIN SECONDARY SCHOOL            All Students
# 5  010001001000  AITKIN SECONDARY SCHOOL            All Students
# 6  010001001000  AITKIN SECONDARY SCHOOL            All Students
# 7  010001001000  AITKIN SECONDARY SCHOOL            All Students
# 8  010001001000  AITKIN SECONDARY SCHOOL          White Students
#
# 3 Ending Status Four Year Percent Four Year Total
# 4      Graduate              90.8              87
# 5      Drop Out               4.6              87
# 6    Continuing               2.3              87
# 7       Unknown               2.3              87
# 8      Graduate             92.31              78

# %%
#Drop all ending statuses except "Graduate"
grad_only = new_grad_df2.loc[new_grad_df2["Ending Status"] == "Graduate", :]
grad_only.head()
# Out:
# 3          ORGID              School Name  \
# 4   010001001000  AITKIN SECONDARY SCHOOL
# 8   010001001000  AITKIN SECONDARY SCHOOL
# 12  010001001000  AITKIN SECONDARY SCHOOL
# 16  010001001000  AITKIN SECONDARY SCHOOL
# 20  010001001000  AITKIN SECONDARY SCHOOL
#
# 3                           Demographic Description Ending Status  \
# 4                                      All Students      Graduate
# 8                                    White Students      Graduate
# 12                       Special Education Students      Graduate
# 16  Students Eligible for Free/Reduced Priced Meals      Graduate
# 20                                    Male Students      Graduate
#
# 3  Four Year Percent Four Year Total
# 4               90.8              87
# 8              92.31              78
# 12               NaN             NaN
# 16             82.93              41
# 20              87.5              40

# %%
#Drop all student groups except "All Students"
all_grad = grad_only.loc[grad_only["Demographic Description"] == "All Students", :]
all_grad.head()
# Out:
# 3           ORGID              School Name Demographic Description  \
# 4    010001001000  AITKIN SECONDARY SCHOOL            All Students
# 28   030001307000           BASIC SKILLS-4            All Students
# 72   030001346000           800 W BROADWAY            All Students
# 96   030001347000         FAIR SENIOR HIGH            All Students
# 128  030001348000                     MERC            All Students
#
# 3   Ending Status Four Year Percent Four Year Total
# 4        Graduate              90.8              87
# 28       Graduate             77.36             106
# 72       Graduate              3.57              28
# 96       Graduate             79.37              63
# 128      Graduate               3.7              27

# %% [markdown]
# ## Address Data

# %%
#Import file with individual school addresses
school_file = "Resources/MDEExtract_District_School_07-06-2019 with Addresses.csv"

school_df = pd.read_csv(school_file)
school_df
# Out:
#       District Number  District Type  School Number       Number  \
# 0                   1              1              0      0001-01
# 1                   1              1              1  0001-01-001
# 2                   1              1              2  0001-01-002
# 3                   1              1              6  0001-01-006
# 4                   1              1              8  0001-01-008
# 5                   1              1              8  0001-01-008
# 6                   2              1              0      0002-01
# 7                   2              1              1  0002-01-001
# 8                   2              1              2  0002-01-002
# 9                   2              1              3  0002-01-003
# 10                  4              1              0      0004-01
# 11                  4              1             10  0004-01-010
# 12                  4              1             30  0004-01-030
# ...

# %%
#Rename 'Organization' to 'School Name'
school_df.rename(columns = {'Organization': 'School Name'}, inplace = True) 
school_df['School Name'] = school_df['School Name'].str.upper()

# %%
# Add leading zeros to District Number, District Type and School Number Columns
school_df['District Type'] = school_df['District Type'].map(lambda x: f'{x:0>2}')
school_df['District Number'] = school_df['District Number'].map(lambda x: f'{x:0>4}')
school_df['School Number'] = school_df['School Number'].map(lambda x: f'{x:0>3}')
school_df.head()
# Out:
#   District Number District Type School Number       Number  \
# 0            0001            01           000      0001-01
# 1            0001            01           001  0001-01-001
# 2            0001            01           002  0001-01-002
# 3            0001            01           006  0001-01-006
# 4            0001            01           008  0001-01-008
#
#                            School Name           Title              Name  \
# 0        AITKIN PUBLIC SCHOOL DISTRICT  Superintendent  Dr  Charles Rick
# 1              AITKIN SECONDARY SCHOOL       Principal      Paul Karelis
# 2                RIPPLESIDE ELEMENTARY       Principal    Jesse Peterson
# 3  AITKIN ALTERNATIVE LEARNING PROGRAM       Principal        Gary Blake
# 4                           AITKIN ESY       Principal   Jesse  Peterson
#
#     First Name Last Name                 Phone      ...       Physical Zip  \
# 0  Dr  Charles      Rick        (218) 927-2115      ...         56431-1289
# ...

# %%
# Create ORGID for Address Data
school_df["ORGID"] = school_df["District Type"].apply(str) + school_df["District Number"].apply(str) + school_df["School Number"].apply(str) + "000"
school_df.head()
# Out:
#   District Number District Type School Number       Number  \
# 0            0001            01           000      0001-01
# 1            0001            01           001  0001-01-001
# 2            0001            01           002  0001-01-002
# 3            0001            01           006  0001-01-006
# 4            0001            01           008  0001-01-008
#
#                            School Name           Title              Name  \
# 0        AITKIN PUBLIC SCHOOL DISTRICT  Superintendent  Dr  Charles Rick
# 1              AITKIN SECONDARY SCHOOL       Principal      Paul Karelis
# 2                RIPPLESIDE ELEMENTARY       Principal    Jesse Peterson
# 3  AITKIN ALTERNATIVE LEARNING PROGRAM       Principal        Gary Blake
# 4                           AITKIN ESY       Principal   Jesse  Peterson
#
#     First Name Last Name                 Phone      ...       County Grades  \
# 0  Dr  Charles      Rick        (218) 927-2115      ...       Aitkin    NaN
# ...

# %%
# Create new data frame by dropping unnecessary columns
school_df2 = school_df[[ 'ORGID', 
                         'Physical Line 1', 
                         'Physical City',
                         'Physical State',
                         'Physical Zip']]
school_df2.head()
# Out:
#           ORGID Physical Line 1 Physical City Physical State Physical Zip
# 0  010001000000   306 2nd St NW        Aitkin             MN   56431-1289
# 1  010001001000   306 2nd St NW        Aitkin             MN        56431
# 2  010001002000  225 2nd Ave SW        Aitkin             MN        56431
# 3  010001006000    12 7th St NW        Aitkin             MN        56431
# 4  010001008000   306 2nd St NW        Aitkin             MN        56431

# %%
# Merge cleaned graduation datafrmae with cleaned school address file
merge_df = pd.merge(all_grad, school_df2, on='ORGID')
merge_df.head()
# Out:
#           ORGID              School Name Demographic Description  \
# 0  010001001000  AITKIN SECONDARY SCHOOL            All Students
# 1  030001307000           BASIC SKILLS-4            All Students
# 2  030001346000           800 W BROADWAY            All Students
# 3  030001347000         FAIR SENIOR HIGH            All Students
# 4  030001348000                     MERC            All Students
#
#   Ending Status Four Year Percent Four Year Total       Physical Line 1  \
# 0      Graduate              90.8              87         306 2nd St NW
# 1      Graduate             77.36             106   1250 W Broadway Ave
# 2      Graduate              3.57              28    1250 West Broadway
# 3      Graduate             79.37              63  10 South 10th Street
# 4      Graduate               3.7              27     2539 Pleasant Ave
#
#   Physical City Physical State Physical Zip
# 0        Aitkin             MN        56431
# 1   Minneapolis             MN        55411
# ...

# %%
#Drop duplicates in rows and schools without a grad rate listed
merge_df.drop_duplicates(subset=None, keep='first', inplace=True)
merge_df.dropna(subset=['ORGID'])
clean_merge = merge_df.dropna(subset=["Four Year Percent"])
clean_merge.head()
# Out:
#           ORGID              School Name Demographic Description  \
# 0  010001001000  AITKIN SECONDARY SCHOOL            All Students
# 1  030001307000           BASIC SKILLS-4            All Students
# 2  030001346000           800 W BROADWAY            All Students
# 3  030001347000         FAIR SENIOR HIGH            All Students
# 4  030001348000                     MERC            All Students
#
#   Ending Status Four Year Percent Four Year Total       Physical Line 1  \
# 0      Graduate              90.8              87         306 2nd St NW
# 1      Graduate             77.36             106   1250 W Broadway Ave
# 2      Graduate              3.57              28    1250 West Broadway
# 3      Graduate             79.37              63  10 South 10th Street
# 4      Graduate               3.7              27     2539 Pleasant Ave
#
#   Physical City Physical State Physical Zip
# 0        Aitkin             MN        56431
# 1   Minneapolis             MN        55411
# ...

# %% [markdown]
# ## Attendance Data

# %%
# Read in Northstar File for Attendance Data
north_file = "Resources/2018 North Star Accountability File 09.07.18 (1).xlsx"
northstar = pd.read_excel(north_file, sheet_name='School')

new_head = northstar.iloc[3] 
northstar_complete = northstar[4:] 
northstar_complete.columns = new_head
northstar_complete.head()
# Out:
# 3        Accountability Year District Number District Type  \
# 4  Identification Year: 2018               1             1
# 5  Identification Year: 2018               1             1
# 6  Identification Year: 2018               1             1
# 7  Identification Year: 2018               1             1
# 8  Identification Year: 2018               1             1
#
# 3                  District Name School Number School Type  \
# 4  Aitkin Public School District             1           H
# 5  Aitkin Public School District             1       H
# 6  Aitkin Public School District             1       H
# 7  Aitkin Public School District             1       H
# 8  Aitkin Public School District             1       H
#
# 3 School Classification              School Name Title I  \
# 4                    33  Aitkin Secondary School       N
# 5                    33  Aitkin Secondary School       N
# 6                    33  Aitkin Secondary School       N
# ...

# %%
# Fill column values and create ORGID column from District Type, District Number and School Number
northstar_complete['District Type'] = northstar_complete['District Type'].map(lambda x: f'{x:0>2}')
northstar_complete['District Number'] = northstar_complete['District Number'].map(lambda x: f'{x:0>4}')
northstar_complete['School Number'] = northstar_complete['School Number'].map(lambda x: f'{x:0>3}')
northstar_complete["ORGID"] = northstar_complete["District Type"].apply(str) + northstar_complete["District Number"].apply(str) + northstar_complete["School Number"].apply(str) + "000"
northstar_complete.head()
# Out:
# 3        Accountability Year District Number District Type  \
# 4  Identification Year: 2018            0001            01
# 5  Identification Year: 2018            0001            01
# 6  Identification Year: 2018            0001            01
# 7  Identification Year: 2018            0001            01
# 8  Identification Year: 2018            0001            01
#
# 3                  District Name School Number School Type  \
# 4  Aitkin Public School District           001           H
# 5  Aitkin Public School District           001       H
# 6  Aitkin Public School District           001       H
# 7  Aitkin Public School District           001       H
# 8  Aitkin Public School District           001       H
#
# 3 School Classification              School Name Title I  \
# 4                    33  Aitkin Secondary School       N
# 5                    33  Aitkin Secondary School       N
# 6                    33  Aitkin Secondary School       N
# ...

# %%
northstar_all = northstar_complete.loc[northstar_complete["Group"] == "ALL", :]
northstar_all.head()
# Out:
# 3         Accountability Year District Number District Type  \
# 4   Identification Year: 2018            0001            01
# 9   Identification Year: 2018            0001            01
# 14  Identification Year: 2018            0001            03
# 23  Identification Year: 2018            0001            03
# 29  Identification Year: 2018            0001            03
#
# 3                        District Name School Number School Type  \
# 4        Aitkin Public School District           001           H
# 9        Aitkin Public School District           002           E
# 14  Minneapolis Public School District           103           E
# 23  Minneapolis Public School District           104           E
# 29  Minneapolis Public School District           105           E
#
# 3  School Classification                    School Name Title I  \
# 4                     33        Aitkin Secondary School       N
# 9                     10          Rippleside Elementary       Y
# ...

# %%
#Create dataframe with ORGID and attendance information
northstar_all.rename(columns = {'Stage 3:\nCons Att': 'Consistent Attendance'}, inplace = True) 
northstar_all['Consistent Attendance'].replace('', np.nan, inplace=True)
northstar_all.dropna(subset=['Consistent Attendance'], inplace=True)
attendance = northstar_all[[ 'ORGID', 'Consistent Attendance']]
attendance.head()
# Out:
# 3          ORGID  Consistent Attendance
# 4   010001001000                  92.35
# 9   010001002000                  90.76
# 14  030001103000                  93.24
# 23  030001104000                  93.53
# 29  030001105000                  83.56

# %%
merge_complete = pd.merge(clean_merge, attendance, on='ORGID')
merge_complete.drop_duplicates(subset=['ORGID'], keep='first', inplace=True)
merge_complete
# Out:
#              ORGID                                 School Name  \
# 0     010001001000                     AITKIN SECONDARY SCHOOL
# 4     030001346000                              800 W BROADWAY
# 6     030001347000                            FAIR SENIOR HIGH
# 9     030001348000                                        MERC
# 13    030001349000                        LORING-NICOLLET HIGH
# 17    030001352000                          EDISON SENIOR HIGH
# 21    030001353000                      LONGFELLOW ALTERNATIVE
# 25    030001354000                           HENRY SENIOR HIGH
# 29    030001357000                       PLYMOUTH YOUTH CENTER
# 33    030001360000                       ROOSEVELT SENIOR HIGH
# 37    030001362000                           SOUTH SENIOR HIGH
# 41    030001363000                WELLSTONE INTERNATIONAL HIGH
# 45    030001364000                       SOUTHWEST SENIOR HIGH
# 49    030001368000                        WASHBURN SENIOR HIGH
# ...

# %%
merge_complete.to_excel(r'Resources\CleanedGradFile2018.xlsx')

# %% [markdown]
# ## Data Analysis

# %%
#Create scatterplot for graduation rate and cohort size
plt.scatter(merge_complete["Four Year Total"], merge_complete["Four Year Percent"], alpha=0.5)
plt.title('Graduation Rate vs. Graduation Cohort Size')
plt.xlabel('Cohort Size')
plt.ylabel('Graduation Rate (%)')
plt.grid(True)
plt.show()

# %%
#Create scatterplot for graduation rate and attendance data
plt.scatter(merge_complete["Consistent Attendance"], merge_complete["Four Year Percent"], alpha=0.5)
plt.title('Graduation Rate vs. Consistent Attendance')
plt.xlabel('Consistent Attendance Rate')
plt.ylabel('Graduation Rate (%)')
plt.grid(True)
plt.show()

# %%
# Create Complete Address row in school data
merge_complete["Complete Address"] = merge_complete["Physical Line 1"] + ", " + merge_complete["Physical City"] + ", " +merge_complete["Physical State"] + " " + merge_complete["Physical Zip"]
merge_complete.head()
# Out:
#            ORGID              School Name Demographic Description  \
# 0   010001001000  AITKIN SECONDARY SCHOOL            All Students
# 4   030001346000           800 W BROADWAY            All Students
# 6   030001347000         FAIR SENIOR HIGH            All Students
# 9   030001348000                     MERC            All Students
# 13  030001349000     LORING-NICOLLET HIGH            All Students
#
#    Ending Status Four Year Percent Four Year Total       Physical Line 1  \
# 0       Graduate              90.8              87         306 2nd St NW
# 4       Graduate              3.57              28    1250 West Broadway
# 6       Graduate             79.37              63  10 South 10th Street
# 9       Graduate               3.7              27     2539 Pleasant Ave
# 13      Graduate              37.5              24   1925 Nicollet Ave S
#
#    Physical City Physical State Physical Zip  Consistent Attendance  \
# ...

# %% [markdown]
# ## Statistical Analysis

# %%
from sklearn.linear_model import LinearRegression
from scipy.stats import linregress

# %%
# Set up linear regression between graduation rate and cohort size
cohort = np.array(merge_complete["Four Year Total"]).reshape((-1, 1))
grad = np.array(merge_complete["Four Year Percent"])
cohortmodel = LinearRegression().fit(cohort, grad)

# %%
# Coefficient of determination for graduation rate and cohort size
cohortr_sq = cohortmodel.score(cohort, grad)
print('coefficient of determination:', cohortr_sq)
# Out:
# coefficient of determination: 0.07672831929109214

# %%
# Slope and intercept of determination for graduation rate and cohort size
print('intercept:', cohortmodel.intercept_)
print('slope:', cohortmodel.coef_)
# Out:
# intercept: 69.24305543165606
# slope: [0.05292776]

# %%
#Create scatterplot for graduation rate and cohort size
plt.scatter(merge_complete["Four Year Total"], merge_complete["Four Year Percent"], alpha=0.5)
plt.title('Graduation Rate vs. Graduation Cohort Size')
plt.xlabel('Cohort Size')
plt.ylabel('Graduation Rate (%)')

#cohort_linex = np.linspace(0, 600, 100)
#cohort_liney = cohortmodel.coef_ * cohort_linex + cohortmodel.intercept_
#plt.plot(cohort_linex, cohort_liney, color="green")
plt.plot([0,840], [67,67], color='r', linestyle='--', linewidth=1) #Federal Accountability Threshold for Graduation 
plt.annotate('Federal Accountability Threshold', xy=(215, 180), xycoords='figure points')

plt.grid(True)
plt.savefig('Images/CohortScatterwithTrend.png')
plt.show()

# %%
# Set up linear regression between graduation rate and attendance
attendance = np.array(merge_complete["Consistent Attendance"]).reshape((-1, 1))
grad = np.array(merge_complete["Four Year Percent"])
attendancemodel = LinearRegression().fit(attendance, grad)

# %%
# Coefficient of determination for graduation rate and attendance
attendancer_sq = attendancemodel.score(attendance, grad)
print('coefficient of determination:', attendancer_sq)
# Out:
# coefficient of determination: 0.48785369112438987

# %%
# Slope and intercept of determination for graduation rate and attendance
print('intercept:', attendancemodel.intercept_)
print('slope:', attendancemodel.coef_)
# Out:
# intercept: 22.91876617498128
# slope: [0.74130793]

# %%
#Create scatterplot for graduation rate and cohort size
plt.scatter(merge_complete["Consistent Attendance"], merge_complete["Four Year Percent"], alpha=0.5)
plt.title('Graduation Rate vs. Consistent Attendance Rate')
plt.xlabel('Consistent Attendance (%)')
plt.ylabel('Graduation Rate (%)')

attendance_linex = np.linspace(0, 100, 100)
attendance_liney = attendancemodel.coef_ * attendance_linex + attendancemodel.intercept_
plt.plot(attendance_linex, attendance_liney, color="green")
plt.plot([0,100], [67,67], color='r', linestyle='--', linewidth=1) #Federal Accountability Threshold for Graduation 
plt.annotate('Federal Accountability Threshold', xy=(60, 180), xycoords='figure points')
plt.plot([95,95], [0,100], color='b', linestyle='--', linewidth=1) #State Attendance Goal
plt.annotate('Attendance', xy=(310, 70), xycoords='figure points')
plt.annotate('Goal Line', xy=(310, 60), xycoords='figure points')

plt.grid(True)
plt.savefig('Images/AttendanceScatterwithTrend.png')
plt.show()

# %%
num_bins = 20
n, bins, patches = plt.hist(cohort, num_bins, alpha=0.75)
plt.xlabel('Cohort Size')
plt.ylabel('Number of Schools')
plt.title(r'Histogram of Cohort Size')
plt.savefig('Images/CohortHistogram.png')
plt.show()

# %%
num_bins = 20
n, bins, patches = plt.hist(attendance, num_bins, alpha=0.75)
plt.xlabel('Consistent Attendance Rate')
plt.ylabel('Number of Schools')
plt.title(r'Histogram of Consistent Attendance Rate')
plt.savefig('Images/AttendanceHistogram.png')
plt.show()

# %%
x = np.array(merge_complete["Four Year Percent"]).reshape((-1, 1))
num_bins = 20
n, bins, patches = plt.hist(x, num_bins, alpha=0.75)
plt.xlabel('Graduation Rate')
plt.ylabel('Number of Schools')
plt.title(r'Histogram of Graduation Rate')
plt.savefig('Images/GradRateHistogram.png')
plt.show()

# %%
# Create histograms to show distribution of cohort size, attendance rate and graduation rate
n_bins = 25
x = np.array(merge_complete["Four Year Percent"]).reshape((-1, 1))

fig, axes = plt.subplots(nrows=1, ncols=3)
ax0, ax1, ax2, = axes.flatten()

ax0.hist(cohort, n_bins, histtype='bar')
ax0.set_title('Histogram of Cohort Size')
ax0.set_xlabel('Cohort Size')
ax0.set_ylabel('Number of Schools')
ax0.set_ylim([0, 225])

ax1.hist(attendance, n_bins, histtype='bar')
ax1.set_title('Histogram of Attendance Rate')
ax1.set_xlabel('Consistent Attendance Rate (%)')
ax1.set_ylim([0, 225])

ax2.hist(x, n_bins, histtype='bar')
ax2.set_title('Histogram of Graduation Rate')
ax2.set_xlabel('Graduation Rate (%)')
ax2.set_ylim([0, 225])

plt.savefig('Images/CombinedHistograms.png')
plt.tight_layout(rect=[0, 0, 2, 2])
plt.show()
