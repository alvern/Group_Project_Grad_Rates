# %%
# %matplotlib notebook

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
file = 'society_redistricting_2010.gpkg'
shp_df = gpd.read_file(file)

# %%
shp_df.head()
# Out:
#            ID       AREA  COLORING            BLOCK    BLOCKGROUP  \
# 0  38861169.0  28.797564         2  271370114002121  271370114002
# 1  38861200.0   0.331563         4  271370114002236  271370114002
# 2  38861216.0   1.500685         2  271370114002116  271370114002
# 3  38861236.0   0.615580         0  271370114002152  271370114002
# 4  38861256.0   0.101863         2  271370114002153  271370114002
#
#          TRACT COUNTY STATE        BLOCK2000         MCD  ... AGIP10 AGR10  \
# 0  27137011400  27137    27  271370114002036  2713770069  ...    0.0   0.0
# 1  27137011400  27137    27  271370114002242  2713770069  ...    0.0   0.0
# 2  27137011400  27137    27  271370114002073  2713770069  ...    0.0   0.0
# 3  27137011400  27137    27  271370114002071  2713770069  ...    0.0   0.0
# 4  27137011400  27137    27  271370114002072  2713770069  ...    0.0   0.0
#
#   AGDFL10 AGTRP10 AGWI10 DEM_INDEX REP_INDEX THIRD_INDE INDEX_VOTE  \
# ...

# %%
shp_df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('census.png')
