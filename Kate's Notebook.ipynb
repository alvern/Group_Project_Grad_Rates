# %%
import pandas as pd
import os
import csv

os.getcwd()
# Out:
# '/Users/Kate/Desktop/Bootcamp/Group Project 1'

# %%
file = "Resources/MN-Fixed-Dec2017-v2.csv"

# %%
mn_broadband = pd.read_csv(file)
mn_broadband.head()
# Out:
#    LogRecNo  Provider_Id       FRN                  ProviderName  \
# 0     18268        34062  15093073  A Better Wireless, NISP, LLC
# 1     18269        34062  15093073  A Better Wireless, NISP, LLC
# 2     18270        34062  15093073  A Better Wireless, NISP, LLC
# 3     18271        34062  15093073  A Better Wireless, NISP, LLC
# 4     18272        34062  15093073  A Better Wireless, NISP, LLC
#
#                         DBAName            HoldingCompanyName  HocoNum  \
# 0  A Better Wireless, NISP, LLC  A Better Wireless, NISP, LLC   290005
# 1  A Better Wireless, NISP, LLC  A Better Wireless, NISP, LLC   290005
# 2  A Better Wireless, NISP, LLC  A Better Wireless, NISP, LLC   290005
# 3  A Better Wireless, NISP, LLC  A Better Wireless, NISP, LLC   290005
# 4  A Better Wireless, NISP, LLC  A Better Wireless, NISP, LLC   290005
#
#                       HocoFinal StateAbbr        BlockCode  TechCode  \
# 0  A Better Wireless, NISP, LLC        MN  271119606002066        70
# ...
