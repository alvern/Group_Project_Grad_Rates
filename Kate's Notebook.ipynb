# %%
import pandas as pd
import os
import csv

os.getcwd()
# Out:
# '/Users/Kate/Desktop/Bootcamp/Group Project 1'

# %%
file = "Resources/MN-Fixed-Dec2017-v2.csv"

# %%
mn_broadband = pd.read_csv(file)
mn_broadband.head(50)
# Out:
#     LogRecNo  Provider_Id       FRN                  ProviderName  \
# 0      18268        34062  15093073  A Better Wireless, NISP, LLC
# 1      18269        34062  15093073  A Better Wireless, NISP, LLC
# 2      18270        34062  15093073  A Better Wireless, NISP, LLC
# 3      18271        34062  15093073  A Better Wireless, NISP, LLC
# 4      18272        34062  15093073  A Better Wireless, NISP, LLC
# 5      18273        34062  15093073  A Better Wireless, NISP, LLC
# 6      18274        34062  15093073  A Better Wireless, NISP, LLC
# 7      18275        34062  15093073  A Better Wireless, NISP, LLC
# 8      18276        34062  15093073  A Better Wireless, NISP, LLC
# 9      18277        34062  15093073  A Better Wireless, NISP, LLC
# 10     18278        34062  15093073  A Better Wireless, NISP, LLC
# 11     18279        34062  15093073  A Better Wireless, NISP, LLC
# 12     18280        34062  15093073  A Better Wireless, NISP, LLC
# ...

# %%
# Clean up dataframe, remove unnecessary columns

mn_broadband = mn_broadband.drop(["LogRecNo", "Provider_Id", "FRN", "HoldingCompanyName", 
                                 "HocoFinal", "HocoNum"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-7f67cb95f91e> in <module>
#       2
#       3 mn_broadband = mn_broadband.drop(["LogRecNo", "Provider_Id", "FRN", "HoldingCompanyName",
# ----> 4                                  "HocoFinal", "HocoNum"], axis=1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
mn_broadband.head()
# Out:
#                    ProviderName                       DBAName StateAbbr  \
# 0  A Better Wireless, NISP, LLC  A Better Wireless, NISP, LLC        MN
# 1  A Better Wireless, NISP, LLC  A Better Wireless, NISP, LLC        MN
# 2  A Better Wireless, NISP, LLC  A Better Wireless, NISP, LLC        MN
# 3  A Better Wireless, NISP, LLC  A Better Wireless, NISP, LLC        MN
# 4  A Better Wireless, NISP, LLC  A Better Wireless, NISP, LLC        MN
#
#          BlockCode  TechCode  Consumer  MaxAdDown  MaxAdUp  Business  \
# 0  271119606002066        70         1     1000.0   1000.0         1
# 1  271119606002068        70         1     1000.0   1000.0         1
# 2  271119606002069        70         1     1000.0   1000.0         1
# 3  271119606002070        70         1     1000.0   1000.0         1
# 4  271119606002071        70         1     1000.0   1000.0         1
#
#    MaxCIRDown  MaxCIRUp
# 0      1000.0    1000.0
# 1      1000.0    1000.0
# 2      1000.0    1000.0
# ...

# %%
# Export new csv
mn_broadband.to_csv('mn_broadband_data.csv')
